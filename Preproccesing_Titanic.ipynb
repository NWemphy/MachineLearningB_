# %% [markdown]
# <a href="https://colab.research.google.com/github/NWemphy/MachineLearningB_/blob/main/Preproccesing_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv('titanic_dataset.csv')

# %%
data_process = data_process.drop(columns=["PassengerId", "Name", "Ticket", "Cabin", "Embarked", "Survived"])

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data_process = data_process.copy()
data_process['label'] = label_encoder.fit_transform(data_process['Sex'])

# %%
dropna1_df = data_process.copy()

# %%
dropna1_df
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare  label
# 0         3    male  22.0      1      0   7.2500      1
# 1         1  female  38.0      1      0  71.2833      0
# 2         3  female  26.0      0      0   7.9250      0
# 3         1  female  35.0      1      0  53.1000      0
# 4         3    male  35.0      0      0   8.0500      1
# ..      ...     ...   ...    ...    ...      ...    ...
# 886       2    male  27.0      0      0  13.0000      1
# 887       1  female  19.0      0      0  30.0000      0
# 888       3  female   NaN      1      2  23.4500      0
# 889       1    male  26.0      0      0  30.0000      1
# 890       3    male  32.0      0      0   7.7500      1
#
# [891 rows x 7 columns]

# %%
# hasilnya hanya tersisa kolom Pclass, Sex, SibSp, Parch, Fare
# ada satu kolom yg dihapus yakni age, hal ini karena kolom ini ada nilai yang null
# jumlah baris tetap sama karena yang dihapus hanya kolom yang memliki nilai null
dropna1_df.dropna(axis =1)
# Out:
#      Pclass     Sex  SibSp  Parch     Fare  label
# 0         3    male      1      0   7.2500      1
# 1         1  female      1      0  71.2833      0
# 2         3  female      0      0   7.9250      0
# 3         1  female      1      0  53.1000      0
# 4         3    male      0      0   8.0500      1
# ..      ...     ...    ...    ...      ...    ...
# 886       2    male      0      0  13.0000      1
# 887       1  female      0      0  30.0000      0
# 888       3  female      1      2  23.4500      0
# 889       1    male      0      0  30.0000      1
# 890       3    male      0      0   7.7500      1
#
# [891 rows x 6 columns]

# %%
dropna2_df = data_process.copy()

# %%
# hasilnya tetap ada 6 kolom Pclass, Sex, Age, SibSp, Parch, Fare
# namun jumlahnya barisnya jadi 714 karena semua baris yang ada null dihapus
# kolom age tidak dihapus namun tetap ada pengurangan karena penghapusan sebelumnya
dropna2_df.dropna(axis = 0)
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare  label
# 0         3    male  22.0      1      0   7.2500      1
# 1         1  female  38.0      1      0  71.2833      0
# 2         3  female  26.0      0      0   7.9250      0
# 3         1  female  35.0      1      0  53.1000      0
# 4         3    male  35.0      0      0   8.0500      1
# ..      ...     ...   ...    ...    ...      ...    ...
# 885       3  female  39.0      0      5  29.1250      0
# 886       2    male  27.0      0      0  13.0000      1
# 887       1  female  19.0      0      0  30.0000      0
# 889       1    male  26.0      0      0  30.0000      1
# 890       3    male  32.0      0      0   7.7500      1
#
# [714 rows x 7 columns]

# %%
fillna1_df = data_process.copy()

# %%
# saya menggunakan seleksi data yang hanya bertipe int/number karna bila tidak akan error
# error karena ada tipe data string di tabel itu yakni sex
fillna1_df.fillna(fillna1_df.select_dtypes(include=['number']).mean(), inplace=True)

# %%
fillna2_df = data_process.copy()

# %%
imputer_mean = SimpleImputer(strategy="mean")

# saya memisahkan dahulu kolom numerik nya saja karena ada kolom string yang tidak bisa dioperasikan
kolom_numerik = fillna2_df.select_dtypes(include=["number"]).columns
fillna2_df_mean = pd.DataFrame(imputer_mean.fit_transform(fillna2_df[kolom_numerik]), columns=kolom_numerik)

# saya menggabungkan kembali kolom non numerik dan numerik nya menjadi satu agar lengkap seperti mulanya
fillna2_df_mean = pd.concat([fillna2_df_mean, fillna2_df.select_dtypes(exclude=["number"])], axis=1)

# %%
imputer_mean = SimpleImputer(strategy="median")

# saya memisahkan dahulu kolom numerik nya saja karena ada kolom string yang tidak bisa dioperasikan
kolom_numerik = fillna2_df.select_dtypes(include=["number"]).columns
fillna2_df_median = pd.DataFrame(imputer_median.fit_transform(fillna2_df[kolom_numerik]), columns=kolom_numerik)

# saya menggabungkan kembali kolom non numerik dan numerik nya menjadi satu agar lengkap seperti mulanya
fillna2_df_median = pd.concat([fillna2_df_median, fillna2_df.select_dtypes(exclude=["number"])], axis=1)

# %% [markdown]
# komentar untuk hasil dari fillna2_df_mean dan fillna2_df_median :
# Strategi "mean" mengisi nilai null dengan rata-rata setiap kolom.
# Strategi "median" mengisi nilai null dengan nilai tengah setiap kolom.
# Nilai yang terisi berbeda tergantung dari strategy yang digunakan

# %%
fillna2_df_mean
# Out:
#      Pclass        Age  SibSp  Parch     Fare  label     Sex
# 0       3.0  22.000000    1.0    0.0   7.2500    1.0    male
# 1       1.0  38.000000    1.0    0.0  71.2833    0.0  female
# 2       3.0  26.000000    0.0    0.0   7.9250    0.0  female
# 3       1.0  35.000000    1.0    0.0  53.1000    0.0  female
# 4       3.0  35.000000    0.0    0.0   8.0500    1.0    male
# ..      ...        ...    ...    ...      ...    ...     ...
# 886     2.0  27.000000    0.0    0.0  13.0000    1.0    male
# 887     1.0  19.000000    0.0    0.0  30.0000    0.0  female
# 888     3.0  29.699118    1.0    2.0  23.4500    0.0  female
# 889     1.0  26.000000    0.0    0.0  30.0000    1.0    male
# 890     3.0  32.000000    0.0    0.0   7.7500    1.0    male
#
# [891 rows x 7 columns]

# %%
fillna2_df_median
# Out:
#      Pclass   Age  SibSp  Parch     Fare  label     Sex
# 0       3.0  22.0    1.0    0.0   7.2500    1.0    male
# 1       1.0  38.0    1.0    0.0  71.2833    0.0  female
# 2       3.0  26.0    0.0    0.0   7.9250    0.0  female
# 3       1.0  35.0    1.0    0.0  53.1000    0.0  female
# 4       3.0  35.0    0.0    0.0   8.0500    1.0    male
# ..      ...   ...    ...    ...      ...    ...     ...
# 886     2.0  27.0    0.0    0.0  13.0000    1.0    male
# 887     1.0  19.0    0.0    0.0  30.0000    0.0  female
# 888     3.0  28.0    1.0    2.0  23.4500    0.0  female
# 889     1.0  26.0    0.0    0.0  30.0000    1.0    male
# 890     3.0  32.0    0.0    0.0   7.7500    1.0    male
#
# [891 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
scaler_minmax = MinMaxScaler()
scaler_zscore = StandardScaler()
fillna1_df['Age'] = scaler_minmax.fit_transform(fillna1_df[["Age"]])
fillna1_df["Fare"] = scaler_zscore.fit_transform(fillna1_df[["Fare"]])

# %%
print("Hasil Normalisasi Min-Max (Age):")
print(fillna1_df[['Age']].head())  # Menampilkan 5 data pertama

print("\nHasil Standarisasi Z-score (Fare):")
print(fillna1_df[['Fare']].head())  # Menampilkan 5 data pertama
# Out:
# Hasil Normalisasi Min-Max (Age):
#         Age
# 0  0.271174
# 1  0.472229
# 2  0.321438
# 3  0.434531
# 4  0.434531
#
# Hasil Standarisasi Z-score (Fare):
#        Fare
# 0 -0.502445
# 1  0.786845
# 2 -0.488854
# 3  0.420730
# 4 -0.486337

# %%
# Mengisi nilai NaN dengan mean
fillna1_df.fillna(fillna1_df.select_dtypes(include=['number']).mean(), inplace=True)

# Normalisasi Min-Max untuk Age
scaler_minmax = MinMaxScaler()
fillna1_df['Age_Scaled'] = scaler_minmax.fit_transform(fillna1_df[['Age']])

# Standarisasi Z-score untuk Fare
scaler_zscore = StandardScaler()
fillna1_df["Fare_Scaled"] = scaler_zscore.fit_transform(fillna1_df[['Fare']])

# Menampilkan hasil
print("DataFrame Setelah Imputasi dan Normalisasi:\n")
print(fillna1_df.head())
# Out:
# DataFrame Setelah Imputasi dan Normalisasi:
#
#    Pclass     Sex       Age  SibSp  Parch      Fare  label  Age_Scaled  \
# 0       3    male  0.271174      1      0 -0.502445      1    0.271174
# 1       1  female  0.472229      1      0  0.786845      0    0.472229
# 2       3  female  0.321438      0      0 -0.488854      0    0.321438
# 3       1  female  0.434531      1      0  0.420730      0    0.434531
# 4       3    male  0.434531      0      0 -0.486337      1    0.434531
#
#    Fare_Scaled
# 0    -0.502445
# 1     0.786845
# 2    -0.488854
# 3     0.420730
# 4    -0.486337

# %%
scaled_df = pd.DataFrame({
    'Age_Scaled': fillna1_df['Age_Scaled'],
    'Fare_Scaled': fillna1_df["Fare_Scaled"]
}, index=fillna1_df.index)

final_df = pd.concat([fillna1_df, scaled_df], axis=1)

# %%
final_df
# Out:
#      Pclass     Sex       Age  SibSp  Parch      Fare  label  Age_Scaled  \
# 0         3    male  0.271174      1      0 -0.502445      1    0.271174
# 1         1  female  0.472229      1      0  0.786845      0    0.472229
# 2         3  female  0.321438      0      0 -0.488854      0    0.321438
# 3         1  female  0.434531      1      0  0.420730      0    0.434531
# 4         3    male  0.434531      0      0 -0.486337      1    0.434531
# ..      ...     ...       ...    ...    ...       ...    ...         ...
# 886       2    male  0.334004      0      0 -0.386671      1    0.334004
# 887       1  female  0.233476      0      0 -0.044381      0    0.233476
# 888       3  female  0.367921      1      2 -0.176263      0    0.367921
# 889       1    male  0.321438      0      0 -0.044381      1    0.321438
# 890       3    male  0.396833      0      0 -0.492378      1    0.396833
#
#      Fare_Scaled  Age_Scaled  Fare_Scaled
# 0      -0.502445    0.271174    -0.502445
# ...

# %%
from google.colab import files

filename = "Hasil_Preprosesing_Titanic_225314043.xlsx"
final_df.to_excel(filename, index=False)

files.download(filename)
